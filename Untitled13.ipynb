# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamBertolotto/Projeto-Genaration/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
#conectar de api
#para coletar dados da api preciso de um endpoint (URL)
url = 'https://api.open-meteo.com/v1/forecast?latitude=-23.090000&longitude=-47.218000&current_weather=true'
#vamos desconbrir se a api está funcionando
resposta = requests.get(url)
#status code 200 é ok
if resposta.status_code == 200:
  #é só chamar o que a gente precisa dos dados
  #dados de api vem no formato de json
  dados_json = resposta.json()
  clima_atual = dados_json.get('current_weather')

  #usar pandas para exibir
  df_clima = pd.DataFrame([clima_atual])
  display(df_clima)
# Out:
#                time  interval  temperature  windspeed  winddirection  is_day  \
# 0  2026-06-08T13:15       900         19.4        2.7             32       1
#
#    weathercode
# 0            0

# %%
#para usar um aversão não instalada do sql usamos
import sqlite3
#para ver os dados usamos o pandas
import pandas as pd


conn = sqlite3.connect(':memory:')
cursor = conn.cursor()


conn.commit()
query_e = '''

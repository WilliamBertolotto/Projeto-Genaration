# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamBertolotto/Calculadora-em-Python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "william"
idade = "31"
cidade = "monte mor"

print(f' mu nome é {nome} e tenho {idade } anos e moro em {cidade}')
# Out:
#  mu nome é william e tenho 31 anos e moro em monte mor

# %%
nome = "william"
idade = 31
cidade = "monte mor"
print(f"meu nome é {nome}, tenho {idade} anos e moro em {cidade}")
# Out:
# meu nome é william, tenho 31 anos e moro em monte mor

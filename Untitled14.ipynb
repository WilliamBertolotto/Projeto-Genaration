# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamBertolotto/Projeto-Genaration/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_clientes_piston = pd.read_csv ('https://chiavinik.github.io/generarionDOM3/' , sep = ',', on_bad_lines= 'warn')
display(df_clientes_piston)
# Out:
# /tmp/ipykernel_1721/89283728.py:2: ParserWarning: Skipping line 5: expected 1 fields, saw 2
# Skipping line 15: expected 1 fields, saw 4
# Skipping line 16: expected 1 fields, saw 4
# Skipping line 26: expected 1 fields, saw 2
# Skipping line 27: expected 1 fields, saw 9
# Skipping line 45: expected 1 fields, saw 4
# Skipping line 59: expected 1 fields, saw 3
# Skipping line 101: expected 1 fields, saw 4
# Skipping line 106: expected 1 fields, saw 2
# Skipping line 112: expected 1 fields, saw 4
# Skipping line 138: expected 1 fields, saw 2
# Skipping line 177: expected 1 fields, saw 4
# Skipping line 187: expected 1 fields, saw 4
# Skipping line 231: expected 1 fields, saw 4
# Skipping line 232: expected 1 fields, saw 4
# Skipping line 263: expected 1 fields, saw 4
# Skipping line 278: expected 1 fields, saw 2
# Skipping line 313: expected 1 fields, saw 3
# Skipping line 315: expected 1 fields, saw 3
# Skipping line 352: expected 1 fields, saw 2
# ...

# %%
df_clientes_piston.info()
df_clientes_piston.describe()

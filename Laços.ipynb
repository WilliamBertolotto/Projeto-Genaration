# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamBertolotto/Projeto-Genaration/blob/main/La%C3%A7os.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
contador =1
while contador < 6:
    pergunta = input('Deseja colocar um valor no contador ? Sim ou Não: ')
    print("valor atual {contador}")

    if pergunta.lower() == 'sim' :
      contador +=1
      print('contador incrementado')
    else:
        print('nenhum valor adicionado')
        print('finalizando o sistema ')
# Out:
# Deseja colocar um valor no contador ? Sim ou Não: sim
# valor atual {contador}
# contador incrementado

# %%
lista =['banana','maça','laranja','uva']
print(len(prateleira))
while (len(prateleira)) <=7 :
  pergunta = input ('Quer adicionar mais frutas ?').lower
  print(f'valor atual {(len(prateleira))}')
  if pergunta == 'Sim':
    nova_fruta = input('Digite o nome da fruta s ser adicionada a prateleira: ')
    prateleira.append(nova_fruta)
    print(f'A fruta {nova_fruta} Foi adicionada com sucesso a prateleira Lo/')
  elif pergunta == 'Não':
      print("Tudo bem então.")
# Out:
# 5
# Quer adicionar mais frutas ?sim
# valor atual 5
# Quer adicionar mais frutas ?sim
# valor atual 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_639/484900962.py in <cell line: 0>()
#       2 print(len(prateleira))
#       3 while (len(prateleira)) <=7 :
# ----> 4   pergunta = input ('Quer adicionar mais frutas ?').lower
#       5   print(f'valor atual {(len(prateleira))}')
#       6   if pergunta == 'Sim':
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
prateleira = ['banana', 'maçã', 'laranja', 'uva']

print(f'Quantidade inicial: {len(prateleira)} frutas')

pergunta = 'sim'

while len(prateleira) <= 7 and pergunta == 'sim':
    pergunta = input('Quer adicionar mais frutas? (Sim/Não): ').lower()

    print(f'Valor atual: {len(prateleira)}')

    if pergunta == 'sim':
        nova_fruta = input('Digite o nome da fruta a ser adicionada à prateleira: ')
        prateleira.append(nova_fruta)
        print(f'A fruta {nova_fruta} foi adicionada a prateleira Lo/')

    elif pergunta == 'não':
        print("Tudo bem então.")

    else:
        print("Resposta inválida. Digite 'Sim' ou 'Não'.")
        pergunta = 'sim'

print("\nFrutas na prateleira:")
for w in prateleira:
    print(fruta)
# Out:
# Quantidade inicial: 4 frutas
# KeyboardInterrupt

# %%
lista_música = []
contador= 1
while contador <= 3:
    música = input(f'Digite o nome de uma música que você goste, {contador}ª música: ')
    lista_música.append(música)
    contador += 1
print("\nLista de músicas:")
for w, música in enumerate(lista_música, start=1):
    print(f'A música {w} é {música}')
# Out:
# Digite o nome de uma música que você goste,1ª música: Bad Romance
# Digite o nome de uma música que você goste,2ª música: The Vatican
# Digite o nome de uma música que você goste,3ª música: The Plague
#
# Lista de músicas:
# A música 1 é Bad Romance
# A música 2 é The Vatican
# A música 3 é The Plague

# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamBertolotto/Projeto-Genaration/blob/main/C%C3%B3digo_das_atividade_de_an%C3%A1lise_de_graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
